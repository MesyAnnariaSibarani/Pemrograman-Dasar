# %% [markdown]
# <a href="https://colab.research.google.com/github/MesyAnnariaSibarani/Pemrograman-Dasar/blob/main/Pertemuan01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya

nama = "Mesy Annaria Sibarani"
tempat_lahir = "Batam"
tanggal_lahir = "25 Mei 2006"
umur = 20
jurusan = "Teknik Elektro"
prodi = "TRPE"
semester = 3
matakuliah = "Pemrograman Dasar"
status_lulus = False

print (nama)
print (tempat_lahir)
print (tanggal_lahir)
print (umur)
print (jurusan)
print (prodi)
print (semester)
print (matakuliah)
print (status_lulus)
# Out:
# Mesy Annaria Sibarani
# Batam
# 25 Mei 2006
# 20
# Teknik Elektro
# TRPE
# 3
# Pemrograman Dasar
# False
